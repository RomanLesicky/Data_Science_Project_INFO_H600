# %% [markdown]
# ---
# # INFO-H600 - Computing Foundations of Data Sciences
#
# ## Team 14 :
#
# Roman Lešický, Theo Abraham, Kevin Straatman, Lara Hansen, Grégoire Van den Eynde and Nicolas Roux
#
# Version of python : 3.11.14 | packaged by conda-forge
#
# ---

# %% [markdown]
# # Library:
#
# ###### The download environment.txt is present within the Github repository of the project https://github.com/RomanLesicky/Data_Science_Project_INFO_H600

# %% [markdown]
# ### How path's are handled in this project:

# %%
from pathlib import Path # We are using the pathlib library for our paths 

# The way the code works is that we first locate the project's root
project_root = Path.cwd().resolve()

# Then we make a variable which hall be used as our data directory path which is sued for everyone in this project 
# For steps 2 till 5 included.

data_dir = project_root / "data" 

# Simple print for as a sanity check
print("Project root:", project_root)
print("Data dir:", data_dir)
# Out:
# Project root: C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600
# Data dir: C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data

# %% [markdown]
# ### Rest of the library:

# %%
from pyspark.sql import SparkSession, functions 
import matplotlib.pyplot as plt

#! To be continued ofc

# %% [markdown]
# ---

# %% [markdown]
# # Overview of the project :
#
# # `WIP`

# %% [markdown]
# ---

# %% [markdown]
# # Step 1:
#
# `TBD`

# %% [markdown]
# # DO NOT FORGET TO DO THE DOCUMENTATION in the `PDF`

# %% [markdown]
# ### 1.0 Set-up of the SparkSession

# %%
# Int this cell we initialise a SparkSession, which can be reused.
# An important part of this code is that indicating to Spark to run all available CPU cores, for each task utilizing Spark.
# Therefore, the use of the code has been warned that when they are running cell which are Spark related this will utilize their whole CPU.
# The reason for doing this is that it gives us parallelism without needing a proper cluster
# Additionally, for larger file size we are allocating 16gb for the heap for the driver and executors (JVM), 200 of shuffles is reasonable and works for larger files 

spark = (SparkSession.builder.appName("MillionPlaylistProject").master("local[*]").config("spark.driver.memory", "16g")      
    .config("spark.executor.memory", "16g").config("spark.driver.maxResultSize", "4g").config("spark.sql.shuffle.partitions", "200").getOrCreate())

spark  # Just for postery we display the session
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://RomanLesicky:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>MillionPlaylistProject</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### 1.1 Reading JSON slices into raw DataFrames using Spark

# %%
"""
This is an important part of the project which needs to be addressed. 

The question "How many slice files / slices do we want to read?" needs to be asked since this determined the trade-off between scalability and practical runtime.
Essentially, the answer to that question is having a sufficient amount of data that our metrics will be good whilst not calculating until forever. 

As a group we have decide to hardcode the value 5 for demonstration purposes, this means that we shall ony use mpd.slice.0 to 4999 so only about 5k playlists. 
The sole reason for this specific value is that it small enough to run very fast and yet demonstrate that the pipeline works. 
Additionally the use can adapt this number via the global variable `NUMBER_OF_SLICES`, but they shall keep in mind the that they are using all the cores of their CPU for this. 

That being said, for practical reasons which concern task's 3 and 4 (5 too) we shall use a dataset that contains 50 slices meaning 50 thousand playlists. 
This value does provides enough data to obtain stable aggregate statistics and similarity scores while keeping computation times manageable on a single machine.

Here we do not use a randomized method to chose the slices, since the data at hand is not ordered nor are we worried with a certain bias since we shall be using the 50k 
version for the actual metric determination. 

For context:

Running the 5k version uses only a couple of gb of ram, whilst using the 50k slice size takes about 14 gb of ram.

"""

# So this global variable is to be changed if one desires for a higher number of slices 
# This is very IMPORTANT this number must not be above 1000, since the database provides only a 1000 slices and could cause an Indexing error.
# If the user choses to put 1000 this represents the entire 32.1 Gb of data which is the full database.
NUMBER_OF_SLICES = 50

# This is the file path to the original Million Playlist Dataset to be used only in this Task, for the rest of the project the data_dir variable is meant to be used.
# This dataset will never be published to github since it's under the .gitignore file. 
data_dir_MGD_Original_Data = project_root / "data_Million_Playlist_Dataset" 

# Function to allow for numeric sorting and not str-related sorting, essentially this function will be used as the key parameter when using the sorted function

def slice_start_key_numeric(path: Path) -> int:
    """
    So, this function allows to extract the numeric "starting" index from filenames. 
    This allows to sort slices in the correct numeric order.
    """
    name = path.name # As an example, for mpd.slice.1000-1999.json
    
    # Here we will split to get the middle and starting string 
    the_numeric_value = name.split(".")[2] # this will split in function of "." so we get a list of ["mpd", "slice", "1000-1999", "json"] here we want 1000-1999 so [2]
    starting_string = the_numeric_value.split("-")[0] # here we split again and we also get a list but we only want the starting string so [0]
    
    # And we return the string into an integer to ger a proper numeric sorting 
    return int(starting_string) 

# Here we load all the "mpd.slice.*.json" type files which we sort in function of their numeric values  
# This creates a list of ordered Path object from all the MDP slice's.
all_slices_of_the_playlists = sorted(data_dir_MGD_Original_Data.glob("mpd.slice.*.json"),key=slice_start_key_numeric) # Here we do use the helper function slice_start_key_numeric as detailed above 

# We build a list of inputs paths for Spark, which we also use for printing the MPD files as a precaution 
input_paths = [str(path) for path in all_slices_of_the_playlists[:NUMBER_OF_SLICES]]

# The printing 
print(f"\nThe number of slices which was inputted by the user = {NUMBER_OF_SLICES}:")
for paths in input_paths:
    print("  ", paths)

# So, here we do start the actual PySpark pipeline where we read the selected slice files as a single Spark DataFrame.
# In here each of the files has the structure: {"info": {...}, "playlists": [ {...}, {...}, ... ]}
playlists_unedited_DataFrame = (spark.read.option("multiLine", True).json(input_paths))

# This means that we can directly parse nested multi-line JSON into a structured DataFrame, so we don’t need to write manual parsing code which would need to be done with Dask.
# Out:
# The number of slices which was inputted by the user = 50:
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.0-999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.1000-1999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.2000-2999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.3000-3999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.4000-4999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.5000-5999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.6000-6999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.7000-7999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.8000-8999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.9000-9999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.10000-10999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.11000-11999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.12000-12999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.13000-13999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.14000-14999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.15000-15999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.16000-16999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.17000-17999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.18000-18999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.19000-19999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.20000-20999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.21000-21999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.22000-22999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.23000-23999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.24000-24999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.25000-25999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.26000-26999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.27000-27999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.28000-28999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.29000-29999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.30000-30999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.31000-31999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.32000-32999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.33000-33999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.34000-34999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.35000-35999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.36000-36999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.37000-37999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.38000-38999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.39000-39999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.40000-40999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.41000-41999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.42000-42999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.43000-43999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.44000-44999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.45000-45999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.46000-46999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.47000-47999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.48000-48999.json
#    C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_Million_Playlist_Dataset\mpd.slice.49000-49999.json

# %% [markdown]
# ### 1.2 Flattening pipeline
#
# # Add more infos here cuz this is a bit meager
#
# > Note: Since our pipeline doesn't run on the entire 32.1 GB but rather on a sub-sample of a couple of slices (50 max) we rely on Spark's built-in schema inference. If we processed all 35 GB or ran on a cluster, we would define an explicit StructType schema to avoid an extra pass over the data.

# %%
"""
This second step of Task 1 consists in a flattening pipeline: we take the slice-level JSON files, extract all playlists, 
and then transform them into a final table with one row per (playlist, track).

From the 1.1 point we ended up with `playlists_unedited_DataFrame` which is a single dataframe "shape" according to how many `NUMBER_OF_SLICES`
the user has chosen. The data that is stored here corresponds to one row per JSON slice file.

Where each row has:
- an `info` struct, and

- a `playlists` array, where each element is a playlist with its own fields (pid, name, num_tracks, tracks, ...) 

For the remainder of the Tasks in this project it is much more convenient to work with "flat" tables rather 
than nested arrays and structs. Therefore we shall be making two table:

1) The first one named playlist-level table, which contains: 

   - one row per playlist
   - 9 columns: pid, name,collaborative,modified_atm,num_tracks, num_albums, num_followers, duration_ms and tracks 
   - This last `tracks` column still stores, for each playlist, the full array of its track entries. We will use it in the next step 
     to create one row per (playlist, track), and it also lets us easily reconstruct the original order of tracks if needed.


2) And a second one, named playlist-track table, which consists of:

   - one row per (playlist, track)
   - 15 columns: same information as the previous one, but we do not have tracks but tracks_pos, track_uri, track_name, artist_uri, artist_name,
                 album_uri, album_name, track_duration_ms

Essentially, the objective of these 2 tables is that we have a "normalized" outlook on the original data that we downloaded. Where:

- `playlists_flat_DataFrame` is a "playlist type" table which mainly contains information about the Playlist themselves 
                             from which specific Playlist metrics can be derived 
                             
- `playlist_track_DataFrame` in the same spirit but for tracks related information 

This helps us to:
- compute aggregate statistics in Task 2, 
- building track similarity from co-occurrences in playlists (Task 3),
- building playlist similarity (Task 4),
- and make a playlist continuation model (Task 5)

As briefly discussed in the markdown cell for section 1.2, we rely on Spark's built-in schema inference for the JSON input. The library inspects the JSON 
files and automatically infers field names and data types (string, long, array, struct, ...). We opted for this approach rather than defining an explicit 
JSON schema because we are not processing the full 32.1 GB of data, and therefore we do not strictly need very fine-grained control over every data type.

We are aware that if this this project needed all the data then a JSON scheme like `StructType` would have been necessary. Which would avoids an
extra pass of schema inference, making the job more robust against slight variations in the input.

In our particular setting, the inferred schema is stable across slices (even for a 50k-playlist subset), so we accept this trade-off between convenience and strictness.
"""

# Firstly we build the `playlists_flat_DataFrame` table: we explode the `playlists` array so that each playlist in each slice becomes its own row,
# and then we select only the playlist-level fields we need (pid, name, counts, duration, tracks).

playlists_DataFrame = playlists_unedited_DataFrame.select(
    functions.explode("playlists").alias("playlist"))

# From each `playlist` struct, we will only select the "playlist" related fields and `tracks` too.

playlists_flat_DataFrame = playlists_DataFrame.select(
    functions.col("playlist.pid").alias("pid"),                 # unique playlist id
    functions.col("playlist.name").alias("name"),               # playlist name
    functions.col("playlist.collaborative").alias("collaborative"),
    functions.col("playlist.modified_at").alias("modified_at"), # last modification timestamp
    functions.col("playlist.num_tracks").alias("num_tracks"),   # number of tracks in the playlist
    functions.col("playlist.num_albums").alias("num_albums"),   # number of distinct albums
    functions.col("playlist.num_followers").alias("num_followers"),
    functions.col("playlist.duration_ms").alias("duration_ms"), # total duration of the playlist
    functions.col("playlist.tracks").alias("tracks")            # still an array of track structs
)

# Secondly, we build the `playlist_track_DataFrame` table in a similar spirit: we explode the `tracks` array inside each playlist 
# and then flatten the nested `track` struct into explicit columns so that each row corresponds to a single (playlist, track) pair with all its metadata.

playlist_track_DataFrame = playlists_flat_DataFrame.select(
    functions.col("pid"),
    functions.col("name").alias("playlist_name"),
    functions.col("num_tracks"),
    functions.col("num_albums"),
    functions.col("num_followers"),
    functions.col("modified_at"),
    functions.col("duration_ms").alias("playlist_duration_ms"),
    functions.explode("tracks").alias("track")   # so here we explode the tracks array to make one row per track
)

# Here the `track` column is still a struct (pos, track_uri, track_name, artist, album, ...), so it needs to be flattened into individual columns, 
# so that each row is a fully explicit (playlist, track) record with all relevant information.

playlist_track_DataFrame = playlist_track_DataFrame.select(
    functions.col("pid"),
    functions.col("playlist_name"),
    functions.col("num_tracks"),
    functions.col("num_albums"),
    functions.col("num_followers"),
    functions.col("modified_at"),
    functions.col("playlist_duration_ms"),

    functions.col("track.pos").alias("track_pos"),             # position of the track in the playlist
    functions.col("track.track_uri").alias("track_uri"),       # Spotify track URI
    functions.col("track.track_name").alias("track_name"),     # track title
    functions.col("track.artist_uri").alias("artist_uri"),     # Spotify artist URI
    functions.col("track.artist_name").alias("artist_name"),   # artist name
    functions.col("track.album_uri").alias("album_uri"),       # Spotify album URI
    functions.col("track.album_name").alias("album_name"),     # album name
    functions.col("track.duration_ms").alias("track_duration_ms")  # duration of the specific track
)

# %% [markdown]
# #### 1.2.1 Scheme of  `playlist-level table` and `playlist–track table`:

# %%
print("Schema of playlist-level table:" + "\n")
playlists_flat_DataFrame.printSchema()

print("\nExample of 5 playlists:")
playlists_flat_DataFrame.show(5, truncate=False)
# Out:
# Schema of playlist-level table:
#
# root
#  |-- pid: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- collaborative: string (nullable = true)
#  |-- modified_at: long (nullable = true)
#  |-- num_tracks: long (nullable = true)
#  |-- num_albums: long (nullable = true)
#  |-- num_followers: long (nullable = true)
#  |-- duration_ms: long (nullable = true)
#  |-- tracks: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- album_name: string (nullable = true)
#  |    |    |-- album_uri: string (nullable = true)
#  |    |    |-- artist_name: string (nullable = true)
#  |    |    |-- artist_uri: string (nullable = true)
#  |    |    |-- duration_ms: long (nullable = true)
#  |    |    |-- pos: long (nullable = true)
#  |    |    |-- track_name: string (nullable = true)
#  |    |    |-- track_uri: string (nullable = true)
#
#
# Example of 5 playlists:
# +-----+------------+-------------+-----------+----------+----------+-------------+-----------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ ...
# |pid  |name        |collaborative|modified_at|num_tracks|num_albums|num_followers|duration_ms|tracks                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# +-----+------------+-------------+-----------+----------+----------+-------------+-----------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ ...
# |45000|Ratch       |false        |1508976000 |88        |70        |1            |20047039   |[{BEYONCÉ [Platinum Edition], spotify:album:2UJwKSBUz6rtW4QLK74kQu, Beyoncé, spotify:artist:6vWDO969PvNqNYHIOW5v0m, 250960, 0, ***Flawless, spotify:track:7tefUew2RUuSAqHyegMoY1}, {Lifestyle, spotify:album:4EZDdNda2DHRyqoDgTpS4l, Rich Gang, spotify:artist:6h2J3dxLnTyURwIUBumKog, 269693, 1, Lifestyle, spotify:track:7DTlsMOQjGysXHpwwpHuPl}, {679 (feat. Remy Boyz), spotify:album:0TyDTzG2zt2tg0wONT9wSU, Fetty Wap, spotify:artist:6PXS4YHDkKvl1wkIl4V8DL, 196693, 2, 679 (feat. Remy Boyz), spotify:track:5NQbUaeTEOGdD6hHcre0dZ}, {T-Pain Presents Happy Hour: The Greatest Hits, spotify:album:184XWylq7ZF0Hn7da4Tr6W, T-Pain, spotify:artist:3aQeKQSyrW4qWr35idm0cy, 231093, 3, Up Down (Do This All Day), spotify:track:6lbhWl34Il0WXm5pX1fM9E}, {Classic Man, spotify:album:6WYHzLqNy9g3zNeqs9IwAA, Jidenna, spotify:artist:4TsHKU8l8Wq7n7OPVikirn, 226000, 4, Classic Man, spotify:track:3G7XYAwtxtoGK7fAm4IlD9}, {What A Time To Be Alive, spotify:album:1ozpmkWcCHwsQ4QTnxOOdT, Drake, spotify:artist:3TVXtAsR1Inumwj472S9r4, 205879, 5, Jumpman, spotify:track:27GmP9AWRs744SzKcpJsTZ}, {Trophy (feat. RahRah The Savage), spotify:album:0Y2KHvhqGZfV0WhYfCJMDb, Kayjo, spotify:artist:6aluZMx3D3TlI8czl28t7d, 242004, 6, Trophy (feat. RahRah The Savage), spotify:track:4kjQQIWei6pohmxluH7Fu6}, {Slime Season 3, spotify:album:2z4c8M8aVzl7CTobIp36KF, Young Thug, spotify:artist:50co4Is1HCEo8bhOyUWKpn, 186453, 7, Drippin', spotify:track:0f85bMoarvHbdIcfhDjSjN}, {I'm Up, spotify:album:4sAB9WulPpnAcig7alDGTg, Young Thug, spotify:artist:50co4Is1HCEo8bhOyUWKpn, 249639, 8, F Cancer (Boosie) [feat. Quavo], spotify:track:1qPK58q90l8KNoWyXsLI2Y}, {The Life Of Pablo, spotify:album:7gsWAHLeT0w7es6FofOXk1, Kanye West, spotify:artist:5K4W6rqBFWDnAN6FQUkS6x, 135920, 9, Father Stretch My Hands Pt. 1, spotify:track:4KW1lqgSr8TKrvBII0Brf8}, {The Life Of Pablo, spotify:album:7gsWAHLeT0w7es6FofOXk1, Kanye West, spotify:artist:5K4W6rqBFWDnAN6FQUkS6x, 199866, 10, Highlights, spotify:track:4qYLPta5HZ36idWiXtqh7B}, {The Life Of Pablo, spotify:album:7gsWAHLeT0w7es6FofOXk1, Kanye West, spotify:artist:5K4W6rqBFWDnAN6FQUkS6x, 323302, 11, 30 Hours, spotify:track:2CHmgtK8OCL28WtIK96u4N}, {The Life Of Pablo, spotify:album:7gsWAHLeT0w7es6FofOXk1, Kanye West, spotify:artist:5K4W6rqBFWDnAN6FQUkS6x, 374413, 12, No More Parties In LA, spotify:track:0zLClc0emc6qUeV1p5nc99}, {Slime Season 3, spotify:album:2z4c8M8aVzl7CTobIp36KF, Young Thug, spotify:artist:50co4Is1HCEo8bhOyUWKpn, 176386, 13, Digits, spotify:track:4cg1yakyRSIOjxKM2I7J1q}, {Uber Everywhere, spotify:album:7asvyIMzbsyAJpbC47wjBV, MadeinTYO, spotify:artist:5SyGEPymt1G2uto47tVWvZ, 153428, 14, Uber Everywhere, spotify:track:7zBPzAjKAqQpcv8F8GCq5s}, {Still Brazy, spotify:album:4nwd6ernojhNIIRifDJoRz, YG, spotify:artist:0A0FS04o6zMoto8OKPsDwY, 196600, 15, Why You Always Hatin?, spotify:track:39hnH8WdPmNT3Q3yzwC9Rg}, {Birds In The Trap Sing McKnight, spotify:album:42WVQWuf1teDysXiOupIZt, Young Thug, spotify:artist:50co4Is1HCEo8bhOyUWKpn, 252256, 16, pick up the phone, spotify:track:20dP2DaMHIAmwWAbp7peSr}, {Wake Up, spotify:album:7vhZcSEXGx8dHt1O5coI7Z, Fetty Wap, spotify:artist:6PXS4YHDkKvl1wkIl4V8DL, 224000, 17, Wake Up, spotify:track:6BOtDFg6GJm0rPUDuNmx57}, {I'm Up, spotify:album:4sAB9WulPpnAcig7alDGTg, Young Thug, spotify:artist:50co4Is1HCEo8bhOyUWKpn, 280831, 18, Hercules, spotify:track:5MD2QLnFM2ChpKAh33z0zr}, {untitled unmastered., spotify:album:0kL3TYRsSXnu0iJvFO3rud, Kendrick Lamar, spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg, 258826, 19, untitled 02 | 06.23.2014., spotify:track:3I0FBDc1c1BLNtXWKVjmFg}, {Clique, spotify:album:2ZQcUtW7OGSsd6LQNcYQoh, JAY Z, spotify:artist:3nFkdlSjzX9mRTtwJOzDYB, 293533, 20, Clique, spotify:track:3rbNV2GI8Vtd8byhUtXZID}, {Hall Of Fame, spotify:album:5RlT8X7XGGLKUhoimrDl54, Big Sean, spotify:artist:0c173mlxpT3dSFRgMO8XPh, 284586, 21, Sierra Leone, spotify:track:08kRN04bnducQfDQWK0qRW}, {Plata O Plomo, spotify:album:1hyd7RYmR54El ...
# |45001|slow it down|false        |1505952000 |80        |77        |1            |20365984   |[{Trouble I'm In, spotify:album:7vF8hqJr5ftey5VxwVYVz0, Twinbed, spotify:artist:0fJrV4zS7nW9fre4bNuGsp, 202500, 0, Trouble I'm In, spotify:track:58NyDMjXSBQ9CG3lcvbLKi}, {Little Neon Limelight, spotify:album:4b6NstMmcJypSQzgj2P5zL, Houndmouth, spotify:artist:7EGwUS3c5dXduO4sMyLWC5, 258480, 1, Darlin', spotify:track:3Neq64Rd5NIYZHmdSIUcli}, {Gift to the People: The Songs Wanted and Now Have, or Didn't Know About, spotify:album:4B8KDCmc260ljhv3NzTgOY, Hollywood Anderson, spotify:artist:3FEdqrYbPI6RE6QT3Ctxmy, 298475, 2, My Bestfriend, spotify:track:5nSvQdWwrKYD1hfUfSTWr3}, {Amos Lee, spotify:album:0hPXaSKyujqCej452raazD, Amos Lee, spotify:artist:0QrowybipCKUDnq5y10PD2, 160453, 3, Colors, spotify:track:72SPsHheqN6J3sI520jT9E}, {Cheers To The Fall, spotify:album:6Blubl1glavmervPJa3QVs, Andra Day, spotify:artist:1c4rxrxy8eDLvMVL1DTiBe, 253342, 4, Rise Up, spotify:track:0tV8pOpiNsKqUys0ilUcXz}, {I Cry When I Laugh, spotify:album:2xVeccmEU0zklK4XSKiDCW, Jess Glynne, spotify:artist:4ScCswdRlyA23odg9thgIO, 182740, 5, My Love - Acoustic, spotify:track:0MVnhm9F7xIu9Lc8t8dL2u}, {The Lumineers, spotify:album:0nRgsLe1she16l3pclpyy7, The Lumineers, spotify:artist:16oZKvXb6WkQlVAjwo2Wbg, 307000, 6, Slow It Down, spotify:track:5OFcjrC1OiRSBylQgF5HDD}, {Feline, spotify:album:0AbUYFSGVNegJoajijrRvM, Ella Eyre, spotify:artist:66TrUkUZ3RM29dqeDQRgyA, 236293, 7, We Don't Have To Take Our Clothes Off, spotify:track:61iyAeMVUNu7vIVqedsBFB}, {Ultraviolence, spotify:album:1ORxRsK3MrSLvh7VQTF01F, Lana Del Rey, spotify:artist:00FQb4jTyendYWaN8pK0wa, 351640, 8, Brooklyn Baby, spotify:track:1NZs6n6hl8UuMaX0UC0YTz}, {Crazy, spotify:album:0hOdcKXM4riRXmpyo71SFs, Daniela Andrade, spotify:artist:0WfaItAbs4vlgIA1cuqGtJ, 242000, 9, Crazy, spotify:track:47jgSvqlKwGyBLPnMfeEZN}, {In A Perfect World, spotify:album:7vByqqEWERubaAEmTWljDU, Kodaline, spotify:artist:4BxCuXFJrSWGi1KHcVqaU4, 232466, 10, High Hopes, spotify:track:5lWXM47w1Npqwv0OMMHP5l}, {Holly, spotify:album:25fIzw6ywy5feNdYNkdrh6, Justin Nozuka, spotify:artist:1uquUYtkdKei0zuhBY9P0t, 320066, 11, Save Him, spotify:track:3xdyeSYdeaBQPs2mvCle9C}, {Crash, spotify:album:3Z72KfamjH9Wc5m9mgVqI7, Dave Matthews Band, spotify:artist:2TI7qyDE0QfyOlnbtfDo7L, 316466, 12, Crash into Me, spotify:track:1HL3yEnYq8LEyFQ3QegA5V}, {Continuum, spotify:album:1Xsprdt1q9rOzTic7b9zYM, John Mayer, spotify:artist:0hEurMDQu99nJRq8pTxO14, 245826, 13, Gravity, spotify:track:3SktMqZmo3M9zbB7oKMIF7}, {x, spotify:album:6NoBzYmh5gUusGPCfg0pct, Ed Sheeran, spotify:artist:6eUKZXaKkcviH0Ku9w2n3V, 241346, 14, Tenerife Sea, spotify:track:6vSwxzO2Qf4BinHSXRwZJe}, {Tracy Chapman, spotify:album:6hmmX5UP4rIvOpGSaPerV8, Tracy Chapman, spotify:artist:7oPgCQqMMXEXrNau5vxYZP, 296800, 15, Fast Car, spotify:track:2M9ro2krNb7nr7HSprkEgo}, {Blood Sugar Sex Magik, spotify:album:30Perjew8HyGkdSmqguYyg, Red Hot Chili Peppers, spotify:artist:0L8ExT028jH3ddEcZwqJJ5, 264306, 16, Under The Bridge, spotify:track:3d9DChrdc6BOeFsbrZ3Is0}, {Fallen Down, spotify:album:0IdP0m4JUSLVaBnPHaW7NN, Michelle Featherstone, spotify:artist:1Y50jSAGSM3NnuzqB8yTsk, 280440, 17, Stay, spotify:track:2Ffs0l4veXSiQ37DovOaCa}, {Chestnut Spoke to Maple, spotify:album:259THtxHs2vvTqcQFOKciC, Justin Nozuka, spotify:artist:1uquUYtkdKei0zuhBY9P0t, 273970, 18, By Your Side, spotify:track:4qLOzLFT0sFORwwKbuuRHI}, {Full Moon Fever, spotify:album:5d71Imt5CIb7LpQwDMQ093, Tom Petty, spotify:artist:2UZMlIwnkgAEDBsw1Rejkn, 256000, 19, Free Fallin', spotify:track:5tVA6TkbaAH9QMITTQRrNv}, {Can't Love, Can't Hurt, spotify:album:6I5vLJXuALJYodn6u3ZhSG, Augustana, spotify:artist:61YE3whKiuRr83j1yOm5M7, 151493, 20, Fire, spotify:track:1Oq7az2QUwTdxZULE1iyWG}, {Shake Your Money Maker, spotify:album:6QU6itggAYKtzjKOMqz8Ch, The Black Crowes, spotify:artist:5krkohEVJYw0qoB5VWwxaC, 329400, 21, She Talks To Angels, spotify:track:37431qrKdYaPF0idZ7o1Zr}, {Revolution, spotify:album:3uczBfJFFSNjSiF8ScC1pA, Miranda Lamb ...
# |45002|Phat Beats  |false        |1466640000 |24        |15        |5            |5127143    |[{Cerulean, spotify:album:2Dt2BZKqxIM5b8hdfmPlP7, Baths, spotify:artist:5zS8r5hRRk1jzD41yYS1NO, 198400, 0, Animals, spotify:track:4qnvETk1dIsnddsWAEsp2B}, {Eternal Champ, spotify:album:11Z9Dy2n1UBn2xM6rY3C43, Sweet Valley, spotify:artist:0Rh2F37PiLjhYaERywNulu, 153390, 1, Where Will I Go, spotify:track:4uvz20rRk1QUB4KmU4mvcr}, {Music By Cavelight, spotify:album:5kEQ9AhNjGvjvplVU3dEkj, Blockhead, spotify:artist:7bHm3B3jJju0q9FUdOgp3b, 228066, 2, Jet Son, spotify:track:35Jzsy0kVkfuamHelyU91R}, {Pembroke, spotify:album:06Pi9nLD8T3fTy0DkJbVaU, James Blake, spotify:artist:53KwLdlmrlCelAZMaLVZqU, 147826, 3, Lock in the Lion, spotify:track:1ZGqqIpic2QmEi1SHiOmIp}, {Eternal Champ, spotify:album:11Z9Dy2n1UBn2xM6rY3C43, Sweet Valley, spotify:artist:0Rh2F37PiLjhYaERywNulu, 147945, 4, No Harm, spotify:track:3Sy9sGM0nobyCQxaLqCUVD}, {Eternal Champ, spotify:album:11Z9Dy2n1UBn2xM6rY3C43, Sweet Valley, spotify:artist:0Rh2F37PiLjhYaERywNulu, 186396, 5, Sentimental Trash, spotify:track:5lKQkqvgGv3Aa1CYKqD8DN}, {Flavors, spotify:album:1nnl1Iq2eSkqvMGsIfV5Wr, Bahwee, spotify:artist:5SiL5Tx9kfR5waAA9PuHDo, 129149, 6, OJ & Cereal, spotify:track:3BdbVWAll2UaixyddUtB11}, {The Branches, spotify:album:1JzXdXaA6cu9Hbi4tmVoGb, Long Arm, spotify:artist:0bUWa3lF2u3S1j1JOVZsdA, 402746, 7, After 4AM, spotify:track:62bQXGTXGsxhQnjI2QmhPY}, {Stay Calm, spotify:album:3D8eCMMwfrjEuq61Oqn5XW, Sweet Valley, spotify:artist:0Rh2F37PiLjhYaERywNulu, 116663, 8, Sidewalk Surfer, spotify:track:0w53PiC4s1BYEos5dibn2u}, {Stay Calm, spotify:album:3D8eCMMwfrjEuq61Oqn5XW, Sweet Valley, spotify:artist:0Rh2F37PiLjhYaERywNulu, 137359, 9, Dunk Dreams 95, spotify:track:0To2URVoMvxNQKrFgqumzM}, {Eternal Champ, spotify:album:11Z9Dy2n1UBn2xM6rY3C43, Sweet Valley, spotify:artist:0Rh2F37PiLjhYaERywNulu, 144515, 10, Bros Beyond, spotify:track:0Oyrj0xSlgD1C3rGV77BzH}, {Eternal Champ, spotify:album:11Z9Dy2n1UBn2xM6rY3C43, Sweet Valley, spotify:artist:0Rh2F37PiLjhYaERywNulu, 134171, 11, Motorcycle Renegade, spotify:track:1fIfQuLGvk2PfpXZcZYoQ9}, {Lucky Shiner, spotify:album:1B4nPyTM8ozZUrp3LU3D9F, Gold Panda, spotify:artist:6xS3zemJD9h94iueQvGqVk, 216373, 12, You, spotify:track:3sUJfv2J82Fi4srktLV2Mi}, {No Mas, spotify:album:0F16kwogrxwESOtXHnqDQI, Javelin, spotify:artist:5hso1dNofaJLy96BpWYIUu, 188840, 13, Vibrationz, spotify:track:6VvtmP6yzSbkIxzqu7p7lw}, {No Mas, spotify:album:0F16kwogrxwESOtXHnqDQI, Javelin, spotify:artist:5hso1dNofaJLy96BpWYIUu, 218026, 14, Intervales Theme, spotify:track:69254zte0W5cfu9HsagFSN}, {The Shining, spotify:album:4qKDGFz5pQH9NJtRx7qPdb, J Dilla, spotify:artist:0IVcLMMbm05VIjnzPkGCyp, 336813, 15, So Far To Go, spotify:track:6CmsmQkg655kIZmg22IlVD}, {Cerulean, spotify:album:2Dt2BZKqxIM5b8hdfmPlP7, Baths, spotify:artist:5zS8r5hRRk1jzD41yYS1NO, 255853, 16, Plea, spotify:track:21hUGuONPXy1kV0o5qVprS}, {Return to Paradise, spotify:album:65lDvadJiOcnR5X5LI80jY, Monster Rally, spotify:artist:3DtnSKmpjFGUzZcccWfG43, 176541, 17, Orchids, spotify:track:4404HlhvpyF8reCVoyGGoa}, {Return to Paradise, spotify:album:65lDvadJiOcnR5X5LI80jY, Monster Rally, spotify:artist:3DtnSKmpjFGUzZcccWfG43, 139376, 18, Dusty, spotify:track:4ZbmSYnLaNfzwOJKNOdERg}, {Turkish Gypsy Music, spotify:album:5fpNtxJiCDhBW86c8nyFum, Ahmet Kusgoz, spotify:artist:4g13ltqWdJlq0FPrjtNf41, 353746, 19, Gecemiz, spotify:track:6g9WRWLx7G9NLqMvhpN51i}, {Emad Sayyah: Lebanese Bellydance, spotify:album:2TFF3WZUaOAVlelZ9HzgX9, Bernhard Adlberger, spotify:artist:3QnwX4bLODvVGuYlKU6Wzj, 197000, 20, Zaar Naar (The Fiery Zaar-Rhythm), spotify:track:7sq6jMMd0yUzH5bwnlplAw}, {The North Borders, spotify:album:7sN6lCgPf1rbZYmA3edMKv, Bonobo, spotify:artist:0cmWgDlu9CwTgxPhf403hb, 352246, 21, Cirrus, spotify:track:2lJ4d8MCT6ZlDRHKJ1br14}, {The North Borders, spotify:album:7sN6lCgPf1rbZYmA3edMKv, Bonobo, spotify:artist:0cmWgDlu9CwTgxPhf403hb, 287728, 22, Sapphire, spotify:track:1d5hX0RYHcDM4aHJHSm5cr}, {Taking up Your Precious ...
# |45003|✌🏽         |false        |1509148800 |77        |63        |3            |17201663   |[{Ocean Eyes, spotify:album:5Afh5z6eTtJ62nfqpKZtGv, Owl City, spotify:artist:07QEuhtrNmmZ0zEcqE9SF6, 228346, 0, Fireflies, spotify:track:1mr3616BzLdhXfJmLmRsO8}, {You Get What You Give, spotify:album:0AXoQGOZDaYSaOo0qCTiCr, Zac Brown Band, spotify:artist:6yJCxee7QumYr820xdIsjo, 273893, 1, Colder Weather, spotify:track:1M2l9ReoabUnvl6Y8jLUe7}, {Vibrate: The Best Of, spotify:album:3gnHdybV7CsMxPGwmzFXyS, Rufus Wainwright, spotify:artist:2PfBzriIMRsCXPDtSy9vg8, 251586, 2, Hallelujah, spotify:track:2u6fRGcaBhpI4uNBHpGv0b}, {Title, spotify:album:5W98Ab4VvQEuFEE4TIe5fE, Meghan Trainor, spotify:artist:6JL8zeS1NmiOftqZTRgdTz, 225053, 3, Like I'm Gonna Lose You, spotify:track:2YlZnw2ikdb837oKMKjBkW}, {Uncaged, spotify:album:50JEs25Ca52Q8lcAkuttuP, Zac Brown Band, spotify:artist:6yJCxee7QumYr820xdIsjo, 324266, 4, Goodbye In Her Eyes, spotify:track:3yM53DMMIioxVy7Pha1hD0}, {Finding Shade, spotify:album:48psE2Kdxk8Wxry2yuPiG6, Honeybrowne, spotify:artist:51mrqc0Dgc0DcMwSpX0CvE, 261040, 5, Texas Angel, spotify:track:0wVkovdZKbcgwjwjUvQAAj}, {The Big Revival, spotify:album:2R5PAxygJ4YeRuSwoalKam, Kenny Chesney, spotify:artist:3grHWM9bx2E9vwJCdlRv9O, 182960, 6, American Kids, spotify:track:1dgWTMoHwTUnQhOQ8SR5fV}, {All The Right Reasons, spotify:album:69ny9Y7VrjVP7JNK0xhYke, Nickelback, spotify:artist:6deZN1bslXzeGvOLaLMOIF, 215106, 7, If Everyone Cared, spotify:track:44w63XqGr3sATAzOnOySgF}, {JEKYLL + HYDE, spotify:album:1xy141zMRluP7YaE94IawT, Zac Brown Band, spotify:artist:6yJCxee7QumYr820xdIsjo, 330400, 8, Dress Blues, spotify:track:1VhvEoQZuQ1wKaLiYV0y74}, {Purpose, spotify:album:7fZH0aUAjY3ay25obOUf2a, Justin Bieber, spotify:artist:1uNFoZAHBGtllmzznpCI3s, 200786, 9, Sorry, spotify:track:69bp2EbF7Q2rqc5N3ylezZ}, {Purpose, spotify:album:7fZH0aUAjY3ay25obOUf2a, Justin Bieber, spotify:artist:1uNFoZAHBGtllmzznpCI3s, 233720, 10, Love Yourself, spotify:track:3hB5DgAiMAQ4DzYbsMq1IT}, {Old Boots, New Dirt, spotify:album:2RIu1R2av2tWEu2MloUE6u, Jason Aldean, spotify:artist:3FfvYsEGaIb52QPXhg4DcH, 219146, 11, Burnin' It Down, spotify:track:4f3ocvNFdJMmGP04kskM2J}, {Purpose, spotify:album:7fZH0aUAjY3ay25obOUf2a, Justin Bieber, spotify:artist:1uNFoZAHBGtllmzznpCI3s, 205680, 12, What Do You Mean?, spotify:track:3pzjHKrQSvXGHQ98dx18HI}, {Your Man, spotify:album:5NATaOfEAcyQFATqWZRKLO, Josh Turner, spotify:artist:7vCtweS8UVAXTyau2j0rDT, 228186, 13, Would You Go With Me, spotify:track:1KhrAWvLIjRlQIJtSTgvsi}, {It's Time, spotify:album:2koUTBXkwUt2uJYv0uezHx, Michael Bublé, spotify:artist:1GxkXlMwML1oSg5eLPiAz3, 225906, 14, Home, spotify:track:4wLZ4zPM9c4oe1VV8ejdWV}, {Chaos And The Calm, spotify:album:5BxvswQSGWrBbVCdx6mFGO, James Bay, spotify:artist:4EzkuveR9pLvDVFNx6foYD, 260533, 15, Let It Go, spotify:track:13HVjjWUZFaWilh2QUJKsP}, {What If We, spotify:album:69d6G8jlDQXmnpP4aV3azk, Brandon Heath, spotify:artist:0W7wIkmxoGQbnZYn2z2sLj, 232693, 16, Give Me Your Eyes, spotify:track:7HQn99HBIBHWkZfTMR8Kki}, {Battle Studies, spotify:album:1V5vQRMWTNGmqwxY8jMVou, John Mayer, spotify:artist:0hEurMDQu99nJRq8pTxO14, 175480, 17, Who Says, spotify:track:0HLWvLKQWpFdPhgk6ym58n}, {Justin Moore, spotify:album:7yI8ppmq1tmqF09Qbi1tcj, Justin Moore, spotify:artist:30e8DmahrEamvLbFRPdWmk, 218853, 18, Small Town USA, spotify:track:5pyB5WEAEwqwl18UaBLeBl}, {Passion: Here For You, spotify:album:0NGmtUx2BoGIxzfaCmLj4O, David Crowder Band, spotify:artist:7DhP3bGT7dzr1dCkkH5mTS, 311533, 19, Shadows - feat. Lecrae, spotify:track:1TOxbHZI9qN1Pe5bhPuMri}, {A Thousand Suns, spotify:album:5uvXx5ZQswNRFCdHR521YZ, Linkin Park, spotify:artist:6XyY86QOPPrYVGvF9ch6wz, 231680, 20, Waiting For The End, spotify:track:5JHNg1hxZFT7TDEphhM4wj}, {Crash My Party, spotify:album:5M8gr5RV2eR6UkztC69ogB, Luke Bryan, spotify:artist:0BvkDsjIUla7X0k6CSWh1I, 185986, 21, I See You, spotify:track:3Z3D2hnbZnveVhTuOifJyt}, {Lukas Graham (Blue Album), spotify:album:6NQ2RNksdSKdtnlFOLJo24, Lukas Graham, spotify:a ...
# |45004|💘💘        |false        |1479081600 |102       |78        |1            |23364932   |[{ANTI, spotify:album:2JNVoEx4psIgNQyEExwQVn, Rihanna, spotify:artist:5pKCCKE2ajJHZ9KAiaK11H, 219320, 0, Work, spotify:track:14WWzenpaEgQZlqPq2nk4v}, {Khalifa, spotify:album:40QPuvt8Ft79Bakb0Jc78f, Wiz Khalifa, spotify:artist:137W8MRPWKqSmrBGDBFSop, 238530, 1, Bake Sale (feat. Travis Scott), spotify:track:2okC0OWtgS86P2LC18IzHy}, {The Life Of Pablo, spotify:album:7gsWAHLeT0w7es6FofOXk1, Kanye West, spotify:artist:5K4W6rqBFWDnAN6FQUkS6x, 135920, 2, Father Stretch My Hands Pt. 1, spotify:track:4KW1lqgSr8TKrvBII0Brf8}, {The Life Of Pablo, spotify:album:7gsWAHLeT0w7es6FofOXk1, Kanye West, spotify:artist:5K4W6rqBFWDnAN6FQUkS6x, 181573, 3, Waves, spotify:track:3nAq2hCr1oWsIU54tS98pL}, {Lil Boat, spotify:album:4bJqW1SBOvsfcEzZwsjdjx, Lil Yachty, spotify:artist:6icQOAFXDZKsumw3YXyusw, 243269, 4, One Night, spotify:track:40yJGQyEaBbIkXpwMFkXip}, {I'm Up, spotify:album:4sAB9WulPpnAcig7alDGTg, Young Thug, spotify:artist:50co4Is1HCEo8bhOyUWKpn, 280831, 5, Hercules, spotify:track:5MD2QLnFM2ChpKAh33z0zr}, {The Art of Hustle, spotify:album:0s9cSoniuN0HfXpwlCpGUF, Yo Gotti, spotify:artist:6Ha4aES39QiVjR0L2lwuwq, 257266, 6, Law, spotify:track:7mhk9WyqZZzvTTCQKfh2iV}, {The Pinkprint, spotify:album:40XGTQ7FN6Y3dZXJhKBe96, Nicki Minaj, spotify:artist:0hCNtLu0JehylgoiP8L4Gh, 268000, 7, Pills N Potions, spotify:track:0nnRUsgfm4uQUYTCIH9NZy}, {The Pinkprint, spotify:album:39WwaUn8HTVZpJJmAuIIHN, Nicki Minaj, spotify:artist:0hCNtLu0JehylgoiP8L4Gh, 237840, 8, Feeling Myself, spotify:track:6Sm2YzLtL8FcyTMONOkiFw}, {The Pinkprint, spotify:album:40XGTQ7FN6Y3dZXJhKBe96, Nicki Minaj, spotify:artist:0hCNtLu0JehylgoiP8L4Gh, 312026, 9, Only, spotify:track:1UZ25gykR30Oewh3dBRtVZ}, {Fénix, spotify:album:2dBgWXp41imu2zBNv9oFxZ, Nicky Jam, spotify:artist:1SupJlEpv7RS2tPNRaHViT, 198706, 10, Hasta el Amanecer, spotify:track:5Fim1gaXBgsiFfsQAfQSDS}, {Nicky Jam Hits, spotify:album:4etANPc5BMELu5yx987Rpx, Nicky Jam, spotify:artist:1SupJlEpv7RS2tPNRaHViT, 195453, 11, Travesuras, spotify:track:1PtL0YQRtq3qxDGUSwZPJ5}, {because the internet, spotify:album:63McpWDS7P0dF06fqXQMCZ, Childish Gambino, spotify:artist:73sIBHcqh3Z3NyqHKZ7FOL, 234215, 12, V. 3005, spotify:track:7wwifjNAb172PtDpKK3CoR}, {2014 Forest Hills Drive, spotify:album:7viNUmZZ8ztn2UB4XB3jIL, J. Cole, spotify:artist:6l3HvQ5sa6mXTsMTB19rO5, 239320, 13, Wet Dreamz, spotify:track:6Ius4TC0L3cN74HT7ENE6e}, {Uber Everywhere, spotify:album:7asvyIMzbsyAJpbC47wjBV, MadeinTYO, spotify:artist:5SyGEPymt1G2uto47tVWvZ, 153428, 14, Uber Everywhere, spotify:track:7zBPzAjKAqQpcv8F8GCq5s}, {ANTI, spotify:album:19O3rXe4nDu9YDcc2tOQVn, Rihanna, spotify:artist:5pKCCKE2ajJHZ9KAiaK11H, 206400, 15, Sex With Me, spotify:track:6WAxKNbZoGNzQTIvdMqkFs}, {Royalty (Deluxe Version), spotify:album:0VWmEVuQ8tA5iA3cCTrgxa, Chris Brown, spotify:artist:7bXgB6jMjp9ATFy66eO08Z, 201253, 16, Back To Sleep, spotify:track:6dlpABcXrQKRU9G00i6Zba}, {PARTYNEXTDOOR 3 (P3), spotify:album:2FXGUAESmG5l9YPrzWPvHI, PARTYNEXTDOOR, spotify:artist:2HPaUgqeutzr3jx5a9WyDV, 235477, 17, Come and See Me (feat. Drake), spotify:track:1wZqJM5FGDEl3FjHDxDyQd}, {Chris Brown, spotify:album:49gaz5rhWWgqCw61M9700v, Chris Brown, spotify:artist:7bXgB6jMjp9ATFy66eO08Z, 229040, 18, Yo (Excuse Me Miss), spotify:track:7DFnq8FYhHMCylykf6ZCxA}, {Free TC, spotify:album:2DtLmzu6cCDYO9U53a6hRA, Ty Dolla $ign, spotify:artist:7c0XG5cIJTrrAgEC3ULPiq, 285240, 19, Blasé (feat. Future & Rae Sremmurd), spotify:track:5suEtW2DUAfvroohjzgatb}, {EVOL, spotify:album:3jJKDKdlwRS584zUlHV2Ly, Future, spotify:artist:1RyvyyTE3xzB2ZywiAwp0i, 173346, 20, Wicked, spotify:track:6BbINUfGabVyiNFJpQXn3x}, {Late Nights: The Album, spotify:album:7DMyQuDPe8xzjC0UDSDa96, Jeremih, spotify:artist:3KV3p5EY4AvKxOlhGHORLg, 238320, 21, oui, spotify:track:0PJIbOdMs3bd5AT8liULMQ}, {Never Home, spotify:album:4aNquHQopWSz94oCGUtg4D, DJ Lizak, spotify:artist:6VoF98E3YOn53LhZA9DZ5H, 219036, 22, Pull Up, spotify:track:6ZYWSjw01VHomHd ...
# +-----+------------+-------------+-----------+----------+----------+-------------+-----------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ ...
# only showing top 5 rows

# %%
print("\nSchema of playlist-track table:" + "\n")
playlist_track_DataFrame.printSchema()

print("\nExample of 5 playlist-track rows:")
playlist_track_DataFrame.show(5, truncate=False)
# Out:
# Schema of playlist-track table:
#
# root
#  |-- pid: long (nullable = true)
#  |-- playlist_name: string (nullable = true)
#  |-- num_tracks: long (nullable = true)
#  |-- num_albums: long (nullable = true)
#  |-- num_followers: long (nullable = true)
#  |-- modified_at: long (nullable = true)
#  |-- playlist_duration_ms: long (nullable = true)
#  |-- track_pos: long (nullable = true)
#  |-- track_uri: string (nullable = true)
#  |-- track_name: string (nullable = true)
#  |-- artist_uri: string (nullable = true)
#  |-- artist_name: string (nullable = true)
#  |-- album_uri: string (nullable = true)
#  |-- album_name: string (nullable = true)
#  |-- track_duration_ms: long (nullable = true)
#
#
# Example of 5 playlist-track rows:
# +-----+-------------+----------+----------+-------------+-----------+--------------------+---------+------------------------------------+-------------------------+-------------------------------------+-----------+------------------------------------+---------------------------------------------+-----------------+
# |pid  |playlist_name|num_tracks|num_albums|num_followers|modified_at|playlist_duration_ms|track_pos|track_uri                           |track_name               |artist_uri                           |artist_name|album_uri                           |album_name                                   |track_duration_ms|
# +-----+-------------+----------+----------+-------------+-----------+--------------------+---------+------------------------------------+-------------------------+-------------------------------------+-----------+------------------------------------+---------------------------------------------+-----------------+
# |45000|Ratch        |88        |70        |1            |1508976000 |20047039            |0        |spotify:track:7tefUew2RUuSAqHyegMoY1|***Flawless              |spotify:artist:6vWDO969PvNqNYHIOW5v0m|Beyoncé    |spotify:album:2UJwKSBUz6rtW4QLK74kQu|BEYONCÉ [Platinum Edition]                   |250960           |
# |45000|Ratch        |88        |70        |1            |1508976000 |20047039            |1        |spotify:track:7DTlsMOQjGysXHpwwpHuPl|Lifestyle                |spotify:artist:6h2J3dxLnTyURwIUBumKog|Rich Gang  |spotify:album:4EZDdNda2DHRyqoDgTpS4l|Lifestyle                                    |269693           |
# |45000|Ratch        |88        |70        |1            |1508976000 |20047039            |2        |spotify:track:5NQbUaeTEOGdD6hHcre0dZ|679 (feat. Remy Boyz)    |spotify:artist:6PXS4YHDkKvl1wkIl4V8DL|Fetty Wap  |spotify:album:0TyDTzG2zt2tg0wONT9wSU|679 (feat. Remy Boyz)                        |196693           |
# |45000|Ratch        |88        |70        |1            |1508976000 |20047039            |3        |spotify:track:6lbhWl34Il0WXm5pX1fM9E|Up Down (Do This All Day)|spotify:artist:3aQeKQSyrW4qWr35idm0cy|T-Pain     |spotify:album:184XWylq7ZF0Hn7da4Tr6W|T-Pain Presents Happy Hour: The Greatest Hits|231093           |
# |45000|Ratch        |88        |70        |1            |1508976000 |20047039            |4        |spotify:track:3G7XYAwtxtoGK7fAm4IlD9|Classic Man              |spotify:artist:4TsHKU8l8Wq7n7OPVikirn|Jidenna    |spotify:album:6WYHzLqNy9g3zNeqs9IwAA|Classic Man                                  |226000           |
# +-----+-------------+----------+----------+-------------+-----------+--------------------+---------+------------------------------------+-------------------------+-------------------------------------+-----------+------------------------------------+---------------------------------------------+-----------------+
# only showing top 5 rows

# %% [markdown]
# ### 1.3 Saving flattened DataFrames locally
#
# `To not run if one doesn't want to locally save the dataframes`
#
# Additionally, to make this cell of code work the user needs to have winutils.exe and hadoop.dll installed locally. This can be found on this github page:
#
# - https://github.com/cdarlint/winutils
#
# The version which was used for this project was hadoop-3.3.6.

# %%
"""
This third sub-part of Task 1 is about saving the flattened DataFrames for later Tasks so that we do not have to 
re-do the whole Step 1 pipeline more than once. This pipeline is very swift for the 5k example but it gets more and more 
heavy when increasing `NUMBER_OF_SLICES`.
"""

# NUMBER_OF_SLICES is defined in Section 1.1

# Here we have a very simple if/else code to decide on the folder's name based on NUMBER_OF_SLICES
if NUMBER_OF_SLICES >= 1000:  # if the user inputted 1000 then that corresponds to the full playlist dataset
    folder_name = "Full_Playlist"
else:  # otherwise we add that specific number as part of the folder name
    folder_name = f"{NUMBER_OF_SLICES}k_Playlists"

# Here we define the correct path
post_task1_dir = project_root / "data_post_Task_1" / folder_name

# Here we use mkdir to make it
post_task1_dir.mkdir(parents=True, exist_ok=True)

# Here is where we save the DataFrames produced in sections 1.1 and 1.2.
# For the playlist-level table, we drop the `tracks` array column to keep only playlist metadata.
# This needs to be done to safely save larger files such as 50k otherwise the code keeps crashing, crucially dropping the task 
# isn't the worst idea since in the playlist related table we do not need these information since they are all track related. 
# And finally all track-level information is already stored explicitly in `playlist_track_DataFrame`, which we also save.

playlists_flat_out = post_task1_dir / "playlists_flat"
playlist_track_out = post_task1_dir / "playlist_track"

# Drop the heavy `tracks` array before writing to avoid OutOfMemory errors for larger NUMBER_OF_SLICES
playlists_flat_to_save = playlists_flat_DataFrame.drop("tracks")

playlists_flat_to_save.write.mode("overwrite").parquet(str(playlists_flat_out))
playlist_track_DataFrame.write.mode("overwrite").parquet(str(playlist_track_out))
# We are in overwrite mode so each time this code cell is run it overwrites what is already present,
# so the user should be cautious.

# Just to make things very clear 
print("\nSaved playlist tables to:")
print(playlists_flat_out)
print(playlist_track_out)
# Out:
# Saved playlist tables to:
# C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_post_Task_1\50k_Playlists\playlists_flat
# C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_post_Task_1\50k_Playlists\playlist_track

# %% [markdown]
# ----

# %% [markdown]
# # Step 2:

# %% [markdown]
# # Do the whole pipeline for 5k and 50k to see if there are any differences !!!

# %% [markdown]
# ### 2.1 Loading processed data from Task 1:

# %% [markdown]
# #### `5k_Playlists`

# %%
# 2) Processed dataset folder (here: the 5k playlists version)
#    This corresponds to the folder that already contains playlists_flat/ and playlist_track/
processed_dir = data_dir / "5k_Playlists"

# 3) Paths to the two Parquet tables
playlists_flat_path = processed_dir / "playlists_flat"
playlist_track_path = processed_dir / "playlist_track"  # or "playlists_track" if that’s the real folder name

print("playlists_flat_path:", playlists_flat_path)
print("playlist_track_path:", playlist_track_path)

# Optional sanity checks (good to run once)
assert playlists_flat_path.exists(), f"Missing folder: {playlists_flat_path}"
assert playlist_track_path.exists(), f"Missing folder: {playlist_track_path}"

# 4) SparkSession
spark = (
    SparkSession.builder
    .appName("MillionPlaylistProject_Tasks2to5")
    .master("local[*]")
    .getOrCreate()
)

# 5) Load the exact same DataFrames you saved before
playlists_flat_DataFrame = spark.read.parquet(str(playlists_flat_path))
playlist_track_DataFrame = spark.read.parquet(str(playlist_track_path))

print("\nLoaded tables successfully.")
print("Number of playlists:", playlists_flat_DataFrame.count())
print("Number of (playlist, track) rows:", playlist_track_DataFrame.count())
# Out:
# playlists_flat_path: C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data\5k_Playlists\playlists_flat
# playlist_track_path: C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data\5k_Playlists\playlist_track
#
# Loaded tables successfully.
# Number of playlists: 5000
# Number of (playlist, track) rows: 334487

# %% [markdown]
# #### `50k_Playlists`

# %%
project_root = Path.cwd().resolve()

data_dir_for_50k = project_root / "data_post_Task_1" / "50k_Playlists"

# 3) Paths to the two Parquet tables
playlists_flat_path = data_dir_for_50k / "playlists_flat"
playlist_track_path = data_dir_for_50k / "playlist_track"  # or "playlists_track" if that’s the real folder name

print("playlists_flat_path:", playlists_flat_path)
print("playlist_track_path:", playlist_track_path)

# Optional sanity checks (good to run once)
assert playlists_flat_path.exists(), f"Missing folder: {playlists_flat_path}"
assert playlist_track_path.exists(), f"Missing folder: {playlist_track_path}"

# 4) SparkSession
spark = (
    SparkSession.builder
    .appName("MillionPlaylistProject_Tasks2to5")
    .master("local[*]")
    .getOrCreate()
)

# 5) Load the exact same DataFrames you saved before
playlists_flat_DataFrame = spark.read.parquet(str(playlists_flat_path))
playlist_track_DataFrame = spark.read.parquet(str(playlist_track_path))

print("\nLoaded tables successfully.")
print("Number of playlists:", playlists_flat_DataFrame.count())
print("Number of (playlist, track) rows:", playlist_track_DataFrame.count())
# Out:
# playlists_flat_path: C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_post_Task_1\50k_Playlists\playlists_flat
# playlist_track_path: C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_post_Task_1\50k_Playlists\playlist_track
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[10], line 13
#      10 print("playlist_track_path:", playlist_track_path)
#      12 # Optional sanity checks (good to run once)
# ---> 13 assert playlists_flat_path.exists(), f"Missing folder: {playlists_flat_path}"
#      14 assert playlist_track_path.exists(), f"Missing folder: {playlist_track_path}"
#      16 # 4) SparkSession
#
# AssertionError: Missing folder: C:\Users\roman\Desktop\Master - ULB\2nd year\Q1\Intro Data Sc\Data_Science_Project_INFO_H600\data_post_Task_1\50k_Playlists\playlists_flat

# %% [markdown]
# ---

# %% [markdown]
# # Step 3:

# %% [markdown]
# ---
